# %%
import pandas as pd

# %%
df = pd.read_csv('act_unified_190.csv')

# %%
df
# Out:
#   state code  state stream                    Requirements Canberra Residents  \
# 0        ACT           190  Department of Home Affairs Criteria:you meet t...
#
#                                Requirements overseas  General Requirements  \
# 0  Department of Home Affairs Criteria:you meet t...                   NaN
#
#     service fee
# 0  $300, $1,175
